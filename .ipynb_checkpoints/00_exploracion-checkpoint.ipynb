# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data/universal_top_spotify_songs.csv")

# %%
df.head()
# Out:
#                spotify_id                  name            artists  \
# 0  7tI8dRuH2Yc6RuoTjxo4dU                   Who              Jimin
# 1  6dOtVTDdiauQNBQEDOtlAB    BIRDS OF A FEATHER      Billie Eilish
# 2  2qSkIjg1o9h3YT9RAgYN75              Espresso  Sabrina Carpenter
# 3  5N3hjp1WNayUPZrA8kJmJP  Please Please Please  Sabrina Carpenter
# 4  6AI3ezQ4o3HUoP6Dhudph3           Not Like Us     Kendrick Lamar
#
#    daily_rank  daily_movement  weekly_movement country snapshot_date  \
# 0           1               0               49     NaN    2024-07-26
# 1           2               0               -1     NaN    2024-07-26
# 2           3               0               -1     NaN    2024-07-26
# 3           4               0               -1     NaN    2024-07-26
# 4           5               0               -1     NaN    2024-07-26
#
#    popularity  is_explicit  ...  key loudness mode  speechiness  acousticness  \
# ...

# %% [markdown]
# spotify_id
# The unique identifier for the song in the Spotify database. (type: str)
#
# name
# The title of the song. (type: str)
#
# artists
# The name(s) of the artist(s) associated with the song. Do split(', ') to convert to a list (type: str)
#
# daily_rank
# The daily rank of the song in the top 50 list. (type: int)
#
# daily_movement
# The change in rankings compared to the previous day. (type: int)
#
# weekly_movement
# The change in rankings compared to the previous week. (type: int)
#
# country
# The ISO code of the country of the Top 50 Playlist. If Null, then the playlist if 'Global Top 50'. (type: str)
#
# snapshot_date
# The date on which the data was collected from the Spotify API. (type: str)
#
# popularity
# A measure of the song's current popularity on Spotify. (type: int)
#
# is_explicit
# Indicates whether the song contains explicit lyrics. (type: bool)explicit lyrics. (type: bool)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1018853 entries, 0 to 1018852
# Data columns (total 25 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   spotify_id          1018853 non-null  object
#  1   name                1018826 non-null  object
#  2   artists             1018826 non-null  object
#  3   daily_rank          1018853 non-null  int64
#  4   daily_movement      1018853 non-null  int64
#  5   weekly_movement     1018853 non-null  int64
#  6   country             1005046 non-null  object
#  7   snapshot_date       1018853 non-null  object
#  8   popularity          1018853 non-null  int64
#  9   is_explicit         1018853 non-null  bool
#  10  duration_ms         1018853 non-null  int64
#  11  album_name          1018334 non-null  object
#  12  album_release_date  1018473 non-null  object
#  13  danceability        1018853 non-null  float64
#  14  energy              1018853 non-null  float64
# ...

# %%
df['snapshot_date'] = pd.to_datetime(df['snapshot_date'])
df['snapshot_date'].head()
# Out:
# 0   2024-07-26
# 1   2024-07-26
# 2   2024-07-26
# 3   2024-07-26
# 4   2024-07-26
# Name: snapshot_date, dtype: datetime64[ns]

# %%
df_chile = df[df.country=='CL']

# %%
df_chile.sort_values(by=['popularity', 'snapshot_date'], ascending=False)
# Out:
#                      spotify_id                                 name  \
# 72399    2qSkIjg1o9h3YT9RAgYN75                             Espresso
# 76042    2qSkIjg1o9h3YT9RAgYN75                             Espresso
# 79692    2qSkIjg1o9h3YT9RAgYN75                             Espresso
# 83338    2qSkIjg1o9h3YT9RAgYN75                             Espresso
# 214747   2qSkIjg1o9h3YT9RAgYN75                             Espresso
# ...                         ...                                  ...
# 978114   1hjRhYpWyqDpPahmSlUTlc             Style (Taylor's Version)
# 978122   45wMBGri1PORPjM9PwFfrS       Blank Space (Taylor's Version)
# 978128   3pv7Q5v2dpdefwdWIvE7yH      Shake It Off (Taylor's Version)
# 978129   045ZeOHPIzhxxsm8bq5kyE  Out Of The Woods (Taylor's Version)
# 1010993  4ZTYnXDN5xBl9yazQ9HpIZ                         SOLO RESPIRA
#
#                           artists  daily_rank  daily_movement  \
# 72399           Sabrina Carpenter          50              -7
# ...

# %%
df_chile[df_chile.spotify_id=='2qSkIjg1o9h3YT9RAgYN75'][['snapshot_date', 'popularity', 'daily_rank']].dropna().plot(x='snapshot_date')
# Out:
# <Axes: xlabel='snapshot_date'>

# %%
df_chile.groupby('snapshot_date').mean(numeric_only=True).plot(subplots=True, figsize=(20,25));

# %%
df_chile.groupby('snapshot_date').median(numeric_only=True).plot(subplots=True, figsize=(20,25));

# %%
df_chile.corr(numeric_only=True, method='spearman')
# Out:
#                   daily_rank  daily_movement  weekly_movement  popularity  \
# daily_rank          1.000000       -0.087018        -0.189259   -0.116012
# daily_movement     -0.087018        1.000000         0.312275   -0.044004
# weekly_movement    -0.189259        0.312275         1.000000   -0.115738
# popularity         -0.116012       -0.044004        -0.115738    1.000000
# is_explicit        -0.159237       -0.022788        -0.031199   -0.069785
# duration_ms         0.003607       -0.002188        -0.003799    0.128328
# danceability       -0.010982       -0.013783        -0.015549    0.111572
# energy              0.099965       -0.004795         0.002806    0.038321
# key                -0.012632       -0.000005        -0.014622    0.042738
# loudness            0.087845        0.003439         0.013235    0.173569
# mode                0.096367       -0.006091        -0.023352    0.074137
# speechiness        -0.026170       -0.023796        -0.046591    0.037362
# ...
